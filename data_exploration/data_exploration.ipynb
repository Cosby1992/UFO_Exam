# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

origDF = pd.read_csv('../code/data_output/orig_times.csv')
optDF = pd.read_csv('../code/data_output/optimized_times.csv')
origDF
origDF.describe().apply(lambda x: '%.6f' % x, axis=1)
# Out:
# count       5000.000000
# mean     1046789.700000
# std       116796.066013
# min       844800.000000
# 25%       973000.000000
# 50%      1030100.000000
# 75%      1097700.000000
# max      2193600.000000
# dtype: object

# %%
optDF.describe()
# Out:
#               times
# count   5000.000000
# mean     409.860000
# std      754.987935
# min      100.000000
# 25%      300.000000
# 50%      300.000000
# 75%      400.000000
# max    31800.000000

# %%
plt.figure(figsize=(5,5))
plt.boxplot(origDF)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.boxplot(optDF)
plt.show()

# %%
origDF.hist()
# Out:
# array([[<AxesSubplot:title={'center':'times'}>]], dtype=object)

# %%
optDF.hist()
# Out:
# array([[<AxesSubplot:title={'center':'times'}>]], dtype=object)

# %%
sele
